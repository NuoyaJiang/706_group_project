# %%
import pandas as pd
import pickle

def load_data():
    with open('data/mtb_cleaned_data.pkl', "rb") as f:
        df = pickle.load(f)
        return df

df = load_data()

# %%
df
# Out:
#          country  year  budget_cpp_dstb  budget_cpp_mdr  e_inc_num  \
# 0    Afghanistan  2018             40.0          1400.0      69000
# 1    Afghanistan  2019             50.0          1500.0      71000
# 2    Afghanistan  2020             40.0          1000.0      71000
# 3    Afghanistan  2021             50.0          1000.0      74000
# 4        Albania  2018              NaN             NaN        500
# ..           ...   ...              ...             ...        ...
# 855       Zambia  2021            156.0          5822.0      60000
# 856     Zimbabwe  2018             29.0          1038.0      32000
# 857     Zimbabwe  2019             38.0          1490.0      31000
# 858     Zimbabwe  2020             41.0          1016.0      29000
# 859     Zimbabwe  2021             50.0          1106.0      31000
#
#      e_rr_pct_new  e_rr_pct_ret          source_rr_new          source_rr_ret  \
# 0             4.5          14.0                  Model           Surveillance
# ...
